# %%
from summa import keywords,summarizer
import pandas as pd
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer

file_name = 'aligned_epg_transcriptions_npo1_npo2.csv'
data = pd.read_csv(file_name)
texts = data['text']

# %%
from collections import OrderedDict
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

nlp = spacy.load('nl_core_news_sm')

class TextRank4Keyword():
    """Extract keywords from text"""
    
    def __init__(self):
        self.d = 0.85 # damping coefficient, usually is .85
        self.min_diff = 1e-5 # convergence threshold
        self.steps = 10 # iteration steps
        self.node_weight = None # save keywords and its weight

    
    def set_stopwords(self, stopwords):  
        """Set stop words"""
        for word in STOP_WORDS.union(set(stopwords)):
            lexeme = nlp.vocab[word]
            lexeme.is_stop = True
    
    def sentence_segment(self, doc, candidate_pos, lower):
        """Store those words only in cadidate_pos"""
        sentences = []
        for sent in doc.sents:
            selected_words = []
            for token in sent:
                # Store words only with cadidate POS tag
                if token.pos_ in candidate_pos and token.is_stop is False:
                    if lower is True:
                        selected_words.append(token.text.lower())
                    else:
                        selected_words.append(token.text)
            sentences.append(selected_words)
        return sentences
        
    def get_vocab(self, sentences):
        """Get all tokens"""
        vocab = OrderedDict()
        i = 0
        for sentence in sentences:
            for word in sentence:
                if word not in vocab:
                    vocab[word] = i
                    i += 1
        return vocab
    
    def get_token_pairs(self, window_size, sentences):
        """Build token_pairs from windows in sentences"""
        token_pairs = list()
        for sentence in sentences:
            for i, word in enumerate(sentence):
                for j in range(i+1, i+window_size):
                    if j >= len(sentence):
                        break
                    pair = (word, sentence[j])
                    if pair not in token_pairs:
                        token_pairs.append(pair)
        return token_pairs
        
    def symmetrize(self, a):
        return a + a.T - np.diag(a.diagonal())
    
    def get_matrix(self, vocab, token_pairs):
        """Get normalized matrix"""
        # Build matrix
        vocab_size = len(vocab)
        g = np.zeros((vocab_size, vocab_size), dtype='float')
        for word1, word2 in token_pairs:
            i, j = vocab[word1], vocab[word2]
            g[i][j] = 1
            
        # Get Symmeric matrix
        g = self.symmetrize(g)
        
        # Normalize matrix by column
        norm = np.sum(g, axis=0)
        g_norm = np.divide(g, norm, where=norm!=0) # this is ignore the 0 element in norm
        
        return g_norm

    
    def get_keywords(self, number=10):
        """Print top number keywords"""
        node_weight = OrderedDict(sorted(self.node_weight.items(), key=lambda t: t[1], reverse=True))
        for i, (key, value) in enumerate(node_weight.items()):
            print(key + ' - ' + str(value))
            if i > number:
                break
        
        
    def analyze(self, text, 
                candidate_pos=['NOUN', 'PROPN'], 
                window_size=4, lower=False, stopwords=list()):
        """Main function to analyze text"""
        
        # Set stop words
        self.set_stopwords(stopwords)
        
        # Parse text by spaCy
        doc = nlp(text)
        
        # Filter sentences
        sentences = self.sentence_segment(doc, candidate_pos, lower) # list of list of words
        # Build vocabulary
        vocab = self.get_vocab(sentences)
        
        # Get token_pairs from windows
        token_pairs = self.get_token_pairs(window_size, sentences)
        
        # Get normalized matrix
        g = self.get_matrix(vocab, token_pairs)
        
        # Initionlization for weight(pagerank value)
        pr = np.array([1] * len(vocab))
        
        # Iteration
        previous_pr = 0
        for epoch in range(self.steps):           
            pr = (1-self.d) + self.d * np.dot(g, pr)
            if sum(abs(previous_pr - pr))  < self.min_diff:
                break
            else:
                previous_pr = pr

        # Get weight for each node
        node_weight = dict()
        for word, index in vocab.items():
            node_weight[word] = pr[index]
        
        self.node_weight = node_weight

# %%
tr4w = TextRank4Keyword()
for idx,t in enumerate(texts[0:10]):
    
    tr4w.analyze(t, candidate_pos = ['NOUN', 'PROPN'], window_size=4, lower=False)
    print(f"document id:{idx}")
    tr4w.get_keywords(10)
    print("\n\n\n")
# Out:
# document id:0
# mensen - 2.036226432882566
# GroenLinks - 1.8395260089859353
# bedrijven - 1.7209105644826668
# middenklasse - 1.6209761868850232
# baas - 1.5726853901780742
# samenleving - 1.5585820120615836
# klimaat - 1.4807793676022936
# inkomens - 1.4128768160593093
# partijen - 1.3766265013674306
# idee - 1.255540175650657
# Nederland - 1.255540175650657
# keer - 1.2409463414947313
#
#
#
#
# document id:1
# mensen - 3.050191290357387
# vrede - 2.4279536024742896
# betekenis - 1.773446162451204
# tijd - 1.6354075961692502
# ouders - 1.447041264329045
# gevoel - 1.3375352590335101
# gemeenschap - 1.2981882732854677
# taal - 1.2790424572838086
# doosje - 1.2632770096957922
# status - 1.2632770096957917
# Munsterkerk - 1.2501362963519203
# meter - 1.1270074668149355
#
#
#
#
# document id:2
# euro - 1.0
# klimaatwet - 1.0
#
#
#
#
# document id:3
# mensen - 4.559352417677301
# agenten - 3.334064489495194
# hotel - 3.0261007784144547
# terroristen - 2.980256936729628
# Turken - 2.7879815105371315
# bodycams - 2.628487183191716
# Sri - 2.3183859555114106
# Noord - 2.2500519566302404
# Nederland - 2.1170762777388936
# NPO - 2.0833138772041004
# compensatie - 2.0637449344678176
# EenVandaag - 2.0262946209312376
#
#
#
#
# document id:4
# mensen - 4.11622199101705
# bodycams - 3.0956144047227343
# agenten - 2.9479667595756065
# terroristen - 2.9259096971710448
# hotel - 2.742115062723379
# Turken - 2.732786762223778
# Noord - 2.3933304718081714
# NPO - 2.3561817224238135
# waardedaling - 2.3195649540854513
# Nederland - 2.275718868366757
# nacht - 2.03869704571712
# Groningen - 2.036863181706395
#
#
#
#
# document id:5
# natuur - 8.43813805981768
# kasteel - 7.3212361539072
# jaar - 5.0867897889896225
# mensen - 4.735508670438552
# beetje - 3.9056985208077735
# soep - 3.802964145158573
# mens - 3.6791236281733517
# toekomst - 3.6241665987868465
# farinata - 3.6013456261030994
# Staatsbosbeheer - 3.322694148216683
# bos - 3.070750477958353
# eeuw - 2.931955422341627
#
#
#
#
# document id:6
# beetje - 3.663503204793865
# soep - 3.48218799116007
# farinata - 3.1360339384682874
# bouillon - 1.929736963164022
# pan - 1.7942306868052538
# WUPS - 1.651200616309481
# buitenkant - 1.6178873259821498
# mosselsoep - 1.510621505131379
# mosselen - 1.403209301823189
# soepje - 1.383144645974085
# saus - 1.3592527556578187
# beslag - 1.312969160572771
#
#
#
#
# document id:7
# Ajax - 3.9503157057400644
# jaar - 2.5020727513059766
# ONDERTITELING - 2.3977631700742212
# keer - 2.109026001323097
# NPO - 1.9891920074238842
# aandacht - 1.8785212281085424
# Poel - 1.844376707667878
# Scherpen - 1.8044456103941546
# ACHTERLOPEN - 1.7449508989102367
# Janssen - 1.6604744392116637
# PSV - 1.6236312698192297
# kampioenschap - 1.6036877267601377
#
#
#
#
# document id:8
# jaar - 10.14568662534006
# Veda - 5.233880181692721
# The - 4.710585157994604
# Who - 4.49958750640117
# mensen - 4.316898224654
# leven - 3.6298450876877077
# Concertgebouw - 3.4876264537354698
# geld - 3.1612349949939156
# wereld - 3.1039846174013332
# dag - 3.0733593372678687
# beetje - 3.046052009466917
# Moon - 2.743866412158037
#
#
#
#
# document id:9
# Timmer - 4.690051501826475
# mevrouw - 4.661249647532288
# Mevrouw - 4.27389858589403
# antwoorden - 3.530017512567019
# Michels - 3.0039730784205045
# categorie - 2.9653028301441915
# vraag - 2.8649025743406176
# term - 2.83035877810546
# stad - 2.8006805376880677
# euro - 2.5440387568758536
# ronde - 2.5201754440533404
# Doesum - 2.4972711581201525

# %%
texts[8]
# Out:
# "'Maar als je dan verplaatst in het', 'gevoel van Veda, begrijp je haar.' 'Dat maakt het niet makkelijker.', 'Maar ik begrijp haar wel.' 'Veda geeft zelf ook te kennen', 'dat ze ermee worstelt...' 'met het proces van doodgaan.' 'Ik ben gewoon heel bang', 'dat als ik doodga...' '...dat ik me dan misschien', 'ergens nog bewust ben van...' 'wat er gebeurt of... dat ik het', verdriet van m'n familie meekrijg. 'Of dat ik eigenlijk', 'sowieso nog iets voel of iets...' 'Ehm... ja...' 'Dan zou het hele doel van niet meer', 'leven zou dan eigenlijk weg zijn.' 'En dan zou ik voor niks', 'iedereen pijn hebben gedaan.' 'Moeilijk.' 'Ja, maar ook kraakhelder, he!' 'Hier valt niets', 'niet aan te begrijpen!' 'Zij voert het woord', 'namens een grote doelgroep...' 'en dat vind ik heel erg knap.' 'Hoe groot is deze doelgroep?', 'De cijfers ken ik niet.' 'Maar ik kom veel in klinieken', 'waar wij filmen...' 'en we zien veel jongeren', 'die worstelen met het leven.' 'Met de druk die ze ervaren, welke', 'stoornis het ook is.' 'Er zijn veel beschadigde jongeren.' 'We hebben wat onderzoek gedaan.' 'Het afgelopen jaar zijn er drie', 'verzoeken van jongeren', 'onder de 20 ingewilligd.' 'Het komt dus wel voor.' 'Hoe is het nu met Veda?' 'Op en af.' 'Op het ene moment is ze blij en', 'vrolijk, zelfs humorvol.' 'Van het ene op het andere moment', 'kan ze omslaan...' 'en dan krijgt ze een black-out.' 'Dat duurt een paar minuten.' 'Dan kan er iets zijn uit de omgeving', 'of iets in haar gedachten', 'wat haar triggert...' 'waardoor ze even de omslag maakt.' 'Heeft de documentaire hierbij', 'geholpen?' 'Dat moet je misschien aan haar', 'vragen.' 'Maar het heeft wel geholpen', 'dat ze gehoord is.' 'Wat ik altijd zie bij kwetsbare', 'mensen die besluiten', 'om een film te laten maken...' 'dat is ook dat het helpt', 'omdat ze het voor een ander doen.' 'Het is makkelijker om het', 'buiten zichzelf te plaatsen.' 'Dat ze het wel willen doen', 'voor andere mensen.' 'En daar krijgt ze ook reacties op.' 'Mensen die haar bedanken.' 'Bedankt dat je dit hebt willen', 'delen.' 'Veel sterkte, oma.' 'Vanavond op NPO 3 om 20.25 uur:' 'Veda beslist zelf', 'met meteen na afloop...' 'een live nabespreking met Veda zelf', 'en deskundigen.' 'Zometeen:', 'Lucas Hamming staat 50 jaar...' 'na het legendarische optreden', 'van The Who...' 'in het Concertgebouw', 'met de rockopera Tommy!' Maar nu eerst Zeg 't M! 'Ga je mij nou close-uppen, nee toch?' 'Kijk, braadwors!' 'Mooi zo.' 'Dag mevrouw.', 'Ik zag u zo naar de zee staren.' 'Ja, dat klopt.' 'Waar dacht u aan?', 'Nergens aan.' 'Dat is het fijne van de zee.' 'Kan dat, nergens aan denken?', 'Ik denk het wel.' 'Hier aan zee wel.' 'Wat gebeurt er dan met u?', 'Weet ik niet, gewoon ontspanning.' 'Je hoort alleen de zee', 'en verder niks.' 'Was u aan ontspanning toe?', 'Ja, ik ben aan het werk.' 'Ik ben uit Zwolle hierheen gereden.', 'Ik heb alles afgeleverd.' 'Ik dacht, ik ga even naar de zee.' 'Wat doet u voor werk?', 'Ja, op de bus rijden.' 'Ik breng scootmobiels naar mensen.' 'Dit is wel even lekker zo', op zo'n dag werken... 'een hele dag op de weg.' 'Ik heb net tentamenweek gehad.' 'Nu ben ik vrij, dus even werken.' 'Maar ik heb niet echt rust,', 'zeg maar.' 'Want u studeert ernaast.Ja.' 'Het is een fijn idee', 'dat alleen de zee er is.' 'Je hoeft verder niks, je kan', 'zo ver kijken als je maar wil.' 'Ik ben 23.' 'Ik denk niet dat veel mensen van', 'mijn leeftijd er zo mee bezig zijn.' 'Nee?Nee, ik denk dat er veel gewoon', 'meegaan met de dagelijkse sleur...' 'de hele dag op hun telefoon zitten', 'en niet kijken wat er verder is.' 'Niet even unwinden aan zee.' 'Nee. Ik denk dat een groot gedeelte', 'dat niet doet.' 'De band Jungle By Night viert', 'dit jaar zijn tienjarig jubileum.' 'Na vijf albums en meer', 'dan 500 concerten...' 'zijn de tieners uitgegroeid', 'tot volwassenen.' 'Het is gewoon een kwestie', 'van keuzes maken.' 'Als ik jullie goed begrijp,', 'ook omdat het getal over tien jaar', 'is gevallen...' 'vinden jullie  ...
